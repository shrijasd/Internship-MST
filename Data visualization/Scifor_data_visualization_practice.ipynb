# %%
import pandas as pd
import numpy as np
from csv import *
import matplotlib.pyplot as plt
import array

# %%
x=[1,2,6,8]
y=[3,8,1,10]
plt.plot(x,y,marker='*')
plt.show()

# %%
a=np.array([0,6])
b=np.array([0,250])
plt.plot(a,b,linestyle='dashed',color='orange')
plt.show()

# %%
x=[0,2,6,8,10,12,14,16]
y=[3,6,9,12,15,18,21,24]
plt.plot(x,y,marker='*')
plt.show()

# %%
data= pd.read_csv('tips.csv')
plt.plot(data['tip'],data['size'])
tip=[1.01,1.66,3.5,3.31,3.61]
size=[2,3,3,2,4]
plt.title("line plot")
plt.plot(tip,size,marker='*',linestyle='dashed',color='orange')
plt.xlabel('tip')
plt.ylabel('size')
# Out:
# Text(0, 0.5, 'size')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from 'tips.csv'
data = pd.read_csv('tips.csv')

# Plot 'tip' against 'size'
plt.plot(data['sex'], data['smoker'])
plt.title('Line Plot of sex against Smoker')
plt.xlabel('sex')
plt.ylabel('smoker')
plt.show()
